# %%
from sklearn.datasets import make_regression

import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline
from matplotlib.animation import FuncAnimation
import matplotlib.animation as animation

# %%
X,y = make_regression(n_samples=100, n_features=1, n_informative=1, n_targets=1,noise=20,random_state=13)

# %%
plt.scatter(X,y)

# %%
b = -520
m = 600
lr = 0.001
all_b = []
all_m = []
all_cost = []

epochs = 30

for i in range(epochs):
    slope_b = 0
    slope_m = 0
    cost = 0
    for j in range(X.shape[0]):
        slope_b = slope_b - 2*(y[j] - (m * X[j]) -  b)
        slope_m = slope_m - 2*(y[j] - (m * X[j]) -  b)*X[j]
        cost = cost + (y[j] - m * X[j] -b) ** 2

    b = b - (lr * slope_b)
    m = m - (lr * slope_m)
    all_b.append(b)
    all_m.append(m)
    all_cost.append(cost)

# %%
fig, ax = plt.subplots(figsize=(9,5))
#fig.set_tight_layout(True)

x_i = np.arange(-3, 3, 0.1)
y_i = x_i*(-27) -150
ax.scatter(X, y)
line, = ax.plot(x_i, x_i*50 - 4, 'r-', linewidth=2)

def update(i):
    label = 'epoch {0}'.format(i + 1)
    line.set_ydata(x_i*all_m[i] + all_b[i])
    ax.set_xlabel(label)
    # return line, ax

anim = FuncAnimation(fig, update, repeat=True, frames=epochs, interval=500)

#f = r"animation4.gif" 
#writergif = animation.PillowWriter(fps=2) 
#anim.save(f, writer=writergif)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\RepositoryGitHub\Machine-Learning-Algorithms\Gradient-Decent\gradient-decent-annimation(both-a-and-b).ipynb Cell 6 line 1
#      <a href='vscode-notebook-cell:/d%3A/RepositoryGitHub/Machine-Learning-Algorithms/Gradient-Decent/gradient-decent-annimation%28both-a-and-b%29.ipynb#W5sZmlsZQ%3D%3D?line=11'>12</a>     ax.set_xlabel(label)
#      <a href='vscode-notebook-cell:/d%3A/RepositoryGitHub/Machine-Learning-Algorithms/Gradient-Decent/gradient-decent-annimation%28both-a-and-b%29.ipynb#W5sZmlsZQ%3D%3D?line=12'>13</a>     # return line, ax
# ---> <a href='vscode-notebook-cell:/d%3A/RepositoryGitHub/Machine-Learning-Algorithms/Gradient-Decent/gradient-decent-annimation%28both-a-and-b%29.ipynb#W5sZmlsZQ%3D%3D?line=14'>15</a> anim = FuncAnimation(fig, update, repeat=True, frames=epochs, interval=500)
#      <a href='vscode-notebook-cell:/d%3A/RepositoryGitHub/Machine-Learning-Algorithms/Gradient-Decent/gradient-decent-annimation%28both-a-and-b%29.ipynb#W5sZmlsZQ%3D%3D?line=16'>17</a> #f = r"animation4.gif"
#      <a href='vscode-notebook-cell:/d%3A/RepositoryGitHub/Machine-Learning-Algorithms/Gradient-Decent/gradient-decent-annimation%28both-a-and-b%29.ipynb#W5sZmlsZQ%3D%3D?line=17'>18</a> #writergif = animation.PillowWriter(fps=2)
#      <a href='vscode-notebook-cell:/d%3A/RepositoryGitHub/Machine-Learning-Algorithms/Gradient-Decent/gradient-decent-annimation%28both-a-and-b%29.ipynb#W5sZmlsZQ%3D%3D?line=18'>19</a> #anim.save(f, writer=writergif)
#
# NameError: name 'epochs' is not defined

# %%
# Cost function
# creating a blank window 
# for the animation 
num_epochs = list(range(0,30))
fig = plt.figure(figsize=(9,5)) 
axis = plt.axes(xlim =(0, 31), ylim =(0, 4500000)) 
  
line, = axis.plot([], [], lw = 2) 
  
xdata, ydata = [], [] 
  
# animation function 
def animate(i): 
    label = 'epoch {0}'.format(i + 1)
    xdata.append(num_epochs[i]) 
    ydata.append(all_cost[i]) 
    line.set_data(xdata, ydata) 
    axis.set_xlabel(label)
      
    return line, 
  
# calling the animation function     
anim = animation.FuncAnimation(fig, animate, frames = 30,repeat=False, interval = 500)

f = r"animation5.gif" 
writergif = animation.PillowWriter(fps=2) 
anim.save(f, writer=writergif)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File c:\Python311\Lib\site-packages\matplotlib\animation.py:231, in AbstractMovieWriter.saving(self, fig, outfile, dpi, *args, **kwargs)
#     230 try:
# --> 231     yield self
#     232 finally:
#
# File c:\Python311\Lib\site-packages\matplotlib\animation.py:1069, in Animation.save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1068 for anim in all_anim:
# -> 1069     anim._init_draw()  # Clear the initial frame
#    1070 frame_number = 0
#
# File c:\Python311\Lib\site-packages\matplotlib\animation.py:1722, in FuncAnimation._init_draw(self)
#    1721         return
# -> 1722     self._draw_frame(frame_data)
#    1723 else:
#
# File c:\Python311\Lib\site-packages\matplotlib\animation.py:1744, in FuncAnimation._draw_frame(self, framedata)
#    1742 # Call the func with framedata and args. If blitting is desired,
#    1743 # func needs to return a sequence of any artists that were modified.
# -> 1744 self._drawn_artists = self._func(framedata, *self._args)
#    1746 if self._blit:
#
# d:\RepositoryGitHub\Machine-Learning-Algorithms\Gradient-Decent\gradient-decent-annimation(both-a-and-b).ipynb Cell 7 line 1
#      <a href='vscode-notebook-cell:/d%3A/RepositoryGitHub/Machine-Learning-Algorithms/Gradient-Decent/gradient-decent-annimation%28both-a-and-b%29.ipynb#W6sZmlsZQ%3D%3D?line=14'>15</a> xdata.append(num_epochs[i])
# ---> <a href='vscode-notebook-cell:/d%3A/RepositoryGitHub/Machine-Learning-Algorithms/Gradient-Decent/gradient-decent-annimation%28both-a-and-b%29.ipynb#W6sZmlsZQ%3D%3D?line=15'>16</a> ydata.append(all_cost[i])
#      <a href='vscode-notebook-cell:/d%3A/RepositoryGitHub/Machine-Learning-Algorithms/Gradient-Decent/gradient-decent-annimation%28both-a-and-b%29.ipynb#W6sZmlsZQ%3D%3D?line=16'>17</a> line.set_data(xdata, ydata)
#
# NameError: name 'all_cost' is not defined
#
# During handling of the above exception, another exception occurred:
#
# IndexError                                Traceback (most recent call last)
# d:\RepositoryGitHub\Machine-Learning-Algorithms\Gradient-Decent\gradient-decent-annimation(both-a-and-b).ipynb Cell 7 line 2
#      <a href='vscode-notebook-cell:/d%3A/RepositoryGitHub/Machine-Learning-Algorithms/Gradient-Decent/gradient-decent-annimation%28both-a-and-b%29.ipynb#W6sZmlsZQ%3D%3D?line=24'>25</a> f = r"animation5.gif"
#      <a href='vscode-notebook-cell:/d%3A/RepositoryGitHub/Machine-Learning-Algorithms/Gradient-Decent/gradient-decent-annimation%28both-a-and-b%29.ipynb#W6sZmlsZQ%3D%3D?line=25'>26</a> writergif = animation.PillowWriter(fps=2)
# ---> <a href='vscode-notebook-cell:/d%3A/RepositoryGitHub/Machine-Learning-Algorithms/Gradient-Decent/gradient-decent-annimation%28both-a-and-b%29.ipynb#W6sZmlsZQ%3D%3D?line=26'>27</a> anim.save(f, writer=writergif)
#
# File c:\Python311\Lib\site-packages\matplotlib\animation.py:1064, in Animation.save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1058     _log.info("Disabling savefig.bbox = 'tight', as it may cause "
#    1059               "frame size to vary, which is inappropriate for "
#    1060               "animation.")
#    1061 # canvas._is_saving = True makes the draw_event animation-starting
#    1062 # callback a no-op; canvas.manager = None prevents resizing the GUI
#    1063 # widget (both are likewise done in savefig()).
# -> 1064 with mpl.rc_context({'savefig.bbox': None}), \
#    1065      writer.saving(self._fig, filename, dpi), \
#    1066      cbook._setattr_cm(self._fig.canvas,
#    1067                        _is_saving=True, manager=None):
#    1068     for anim in all_anim:
#    1069         anim._init_draw()  # Clear the initial frame
#
# File c:\Python311\Lib\contextlib.py:155, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     153     value = typ()
#     154 try:
# --> 155     self.gen.throw(typ, value, traceback)
#     156 except StopIteration as exc:
#     157     # Suppress StopIteration *unless* it's the same exception that
#     158     # was passed to throw().  This prevents a StopIteration
#     159     # raised inside the "with" statement from being suppressed.
#     160     return exc is not value
#
# File c:\Python311\Lib\site-packages\matplotlib\animation.py:233, in AbstractMovieWriter.saving(self, fig, outfile, dpi, *args, **kwargs)
#     231     yield self
#     232 finally:
# --> 233     self.finish()
#
# File c:\Python311\Lib\site-packages\matplotlib\animation.py:497, in PillowWriter.finish(self)
#     496 def finish(self):
# --> 497     self._frames[0].save(
#     498         self.outfile, save_all=True, append_images=self._frames[1:],
#     499         duration=int(1000 / self.fps), loop=0)
#
# IndexError: list index out of range
# Error in callback <function _draw_all_if_interactive at 0x000002201DCD9580> (for post_execute):
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File c:\Python311\Lib\site-packages\matplotlib\pyplot.py:119, in _draw_all_if_interactive()
#     117 def _draw_all_if_interactive():
#     118     if matplotlib.is_interactive():
# --> 119         draw_all()
#
# File c:\Python311\Lib\site-packages\matplotlib\_pylab_helpers.py:132, in Gcf.draw_all(cls, force)
#     130 for manager in cls.get_all_fig_managers():
#     131     if force or manager.canvas.figure.stale:
# --> 132         manager.canvas.draw_idle()
#
# File c:\Python311\Lib\site-packages\matplotlib\backend_bases.py:2054, in FigureCanvasBase.draw_idle(self, *args, **kwargs)
#    2052 if not self._is_idle_drawing:
#    2053     with self._idle_draw_cntx():
# -> 2054         self.draw(*args, **kwargs)
#
# File c:\Python311\Lib\site-packages\matplotlib\backends\backend_agg.py:405, in FigureCanvasAgg.draw(self)
#     401 # Acquire a lock on the shared font cache.
#     402 with RendererAgg.lock, \
#     403      (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     404       else nullcontext()):
# --> 405     self.figure.draw(self.renderer)
#     406     # A GUI class may be need to update a window using this draw, so
#     407     # don't forget to call the superclass.
#     408     super().draw()
#
# File c:\Python311\Lib\site-packages\matplotlib\artist.py:74, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      72 @wraps(draw)
#      73 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 74     result = draw(artist, renderer, *args, **kwargs)
#      75     if renderer._rasterizing:
#      76         renderer.stop_rasterizing()
#
# File c:\Python311\Lib\site-packages\matplotlib\artist.py:51, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      48     if artist.get_agg_filter() is not None:
#      49         renderer.start_filter()
# ---> 51     return draw(artist, renderer)
#      52 finally:
#      53     if artist.get_agg_filter() is not None:
#
# File c:\Python311\Lib\site-packages\matplotlib\figure.py:3092, in Figure.draw(self, renderer)
#    3089 finally:
#    3090     self.stale = False
# -> 3092 DrawEvent("draw_event", self.canvas, renderer)._process()
#
# File c:\Python311\Lib\site-packages\matplotlib\backend_bases.py:1230, in Event._process(self)
#    1228 def _process(self):
#    1229     """Generate an event with name ``self.name`` on ``self.canvas``."""
# -> 1230     self.canvas.callbacks.process(self.name, self)
#
# File c:\Python311\Lib\site-packages\matplotlib\cbook\__init__.py:312, in CallbackRegistry.process(self, s, *args, **kwargs)
#     310 except Exception as exc:
#     311     if self.exception_handler is not None:
# --> 312         self.exception_handler(exc)
#     313     else:
#     314         raise
#
# File c:\Python311\Lib\site-packages\matplotlib\cbook\__init__.py:96, in _exception_printer(exc)
#      94 def _exception_printer(exc):
#      95     if _get_running_interactive_framework() in ["headless", None]:
# ---> 96         raise exc
#      97     else:
#      98         traceback.print_exc()
#
# File c:\Python311\Lib\site-packages\matplotlib\cbook\__init__.py:307, in CallbackRegistry.process(self, s, *args, **kwargs)
#     305 if func is not None:
#     306     try:
# --> 307         func(*args, **kwargs)
#     308     # this does not capture KeyboardInterrupt, SystemExit,
#     309     # and GeneratorExit
#     310     except Exception as exc:
#
# File c:\Python311\Lib\site-packages\matplotlib\animation.py:900, in Animation._start(self, *args)
#     897 self._fig.canvas.mpl_disconnect(self._first_draw_id)
#     899 # Now do any initial draw
# --> 900 self._init_draw()
#     902 # Add our callback for stepping the animation and
#     903 # actually start the event_source.
#     904 self.event_source.add_callback(self._step)
#
# File c:\Python311\Lib\site-packages\matplotlib\animation.py:1722, in FuncAnimation._init_draw(self)
#    1714         warnings.warn(
#    1715             "Can not start iterating the frames for the initial draw. "
#    1716             "This can be caused by passing in a 0 length sequence "
#    (...)
#    1719             "it may be exhausted due to a previous display or save."
#    1720         )
#    1721         return
# -> 1722     self._draw_frame(frame_data)
#    1723 else:
#    1724     self._drawn_artists = self._init_func()
#
# File c:\Python311\Lib\site-packages\matplotlib\animation.py:1744, in FuncAnimation._draw_frame(self, framedata)
#    1740 self._save_seq = self._save_seq[-self.save_count:]
#    1742 # Call the func with framedata and args. If blitting is desired,
#    1743 # func needs to return a sequence of any artists that were modified.
# -> 1744 self._drawn_artists = self._func(framedata, *self._args)
#    1746 if self._blit:
#    1748     err = RuntimeError('The animation function must return a sequence '
#    1749                        'of Artist objects.')
#
# d:\RepositoryGitHub\Machine-Learning-Algorithms\Gradient-Decent\gradient-decent-annimation(both-a-and-b).ipynb Cell 7 line 1
#      <a href='vscode-notebook-cell:/d%3A/RepositoryGitHub/Machine-Learning-Algorithms/Gradient-Decent/gradient-decent-annimation%28both-a-and-b%29.ipynb#W6sZmlsZQ%3D%3D?line=13'>14</a> label = 'epoch {0}'.format(i + 1)
#      <a href='vscode-notebook-cell:/d%3A/RepositoryGitHub/Machine-Learning-Algorithms/Gradient-Decent/gradient-decent-annimation%28both-a-and-b%29.ipynb#W6sZmlsZQ%3D%3D?line=14'>15</a> xdata.append(num_epochs[i])
# ---> <a href='vscode-notebook-cell:/d%3A/RepositoryGitHub/Machine-Learning-Algorithms/Gradient-Decent/gradient-decent-annimation%28both-a-and-b%29.ipynb#W6sZmlsZQ%3D%3D?line=15'>16</a> ydata.append(all_cost[i])
#      <a href='vscode-notebook-cell:/d%3A/RepositoryGitHub/Machine-Learning-Algorithms/Gradient-Decent/gradient-decent-annimation%28both-a-and-b%29.ipynb#W6sZmlsZQ%3D%3D?line=16'>17</a> line.set_data(xdata, ydata)
#      <a href='vscode-notebook-cell:/d%3A/RepositoryGitHub/Machine-Learning-Algorithms/Gradient-Decent/gradient-decent-annimation%28both-a-and-b%29.ipynb#W6sZmlsZQ%3D%3D?line=17'>18</a> axis.set_xlabel(label)
#
# NameError: name 'all_cost' is not defined

# %%
# intercept graph
num_epochs = list(range(0,30))
fig = plt.figure(figsize=(9,5)) 
axis = plt.axes(xlim =(0, 31), ylim =(-10, 160)) 
  
line, = axis.plot([], [], lw = 2) 
  
xdata, ydata = [], [] 
  
# animation function 
def animate(i): 
    label = 'epoch {0}'.format(i + 1)
    xdata.append(num_epochs[i]) 
    ydata.append(all_b[i]) 
    line.set_data(xdata, ydata) 
    axis.set_xlabel(label)
      
    return line, 
  
# calling the animation function     
anim = animation.FuncAnimation(fig, animate, frames = 30,repeat=False, interval = 500)

f = r"animation6.gif" 
writergif = animation.PillowWriter(fps=2) 
anim.save(f, writer=writergif)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File c:\Python311\Lib\site-packages\matplotlib\animation.py:231, in AbstractMovieWriter.saving(self, fig, outfile, dpi, *args, **kwargs)
#     230 try:
# --> 231     yield self
#     232 finally:
#
# File c:\Python311\Lib\site-packages\matplotlib\animation.py:1069, in Animation.save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1068 for anim in all_anim:
# -> 1069     anim._init_draw()  # Clear the initial frame
#    1070 frame_number = 0
#
# File c:\Python311\Lib\site-packages\matplotlib\animation.py:1722, in FuncAnimation._init_draw(self)
#    1721         return
# -> 1722     self._draw_frame(frame_data)
#    1723 else:
#
# File c:\Python311\Lib\site-packages\matplotlib\animation.py:1744, in FuncAnimation._draw_frame(self, framedata)
#    1742 # Call the func with framedata and args. If blitting is desired,
#    1743 # func needs to return a sequence of any artists that were modified.
# -> 1744 self._drawn_artists = self._func(framedata, *self._args)
#    1746 if self._blit:
#
# d:\RepositoryGitHub\Machine-Learning-Algorithms\Gradient-Decent\gradient-decent-annimation(both-a-and-b).ipynb Cell 8 line 1
#      <a href='vscode-notebook-cell:/d%3A/RepositoryGitHub/Machine-Learning-Algorithms/Gradient-Decent/gradient-decent-annimation%28both-a-and-b%29.ipynb#X10sZmlsZQ%3D%3D?line=12'>13</a> xdata.append(num_epochs[i])
# ---> <a href='vscode-notebook-cell:/d%3A/RepositoryGitHub/Machine-Learning-Algorithms/Gradient-Decent/gradient-decent-annimation%28both-a-and-b%29.ipynb#X10sZmlsZQ%3D%3D?line=13'>14</a> ydata.append(all_b[i])
#      <a href='vscode-notebook-cell:/d%3A/RepositoryGitHub/Machine-Learning-Algorithms/Gradient-Decent/gradient-decent-annimation%28both-a-and-b%29.ipynb#X10sZmlsZQ%3D%3D?line=14'>15</a> line.set_data(xdata, ydata)
#
# NameError: name 'all_b' is not defined
#
# During handling of the above exception, another exception occurred:
#
# IndexError                                Traceback (most recent call last)
# d:\RepositoryGitHub\Machine-Learning-Algorithms\Gradient-Decent\gradient-decent-annimation(both-a-and-b).ipynb Cell 8 line 2
#      <a href='vscode-notebook-cell:/d%3A/RepositoryGitHub/Machine-Learning-Algorithms/Gradient-Decent/gradient-decent-annimation%28both-a-and-b%29.ipynb#X10sZmlsZQ%3D%3D?line=22'>23</a> f = r"animation6.gif"
#      <a href='vscode-notebook-cell:/d%3A/RepositoryGitHub/Machine-Learning-Algorithms/Gradient-Decent/gradient-decent-annimation%28both-a-and-b%29.ipynb#X10sZmlsZQ%3D%3D?line=23'>24</a> writergif = animation.PillowWriter(fps=2)
# ---> <a href='vscode-notebook-cell:/d%3A/RepositoryGitHub/Machine-Learning-Algorithms/Gradient-Decent/gradient-decent-annimation%28both-a-and-b%29.ipynb#X10sZmlsZQ%3D%3D?line=24'>25</a> anim.save(f, writer=writergif)
#
# File c:\Python311\Lib\site-packages\matplotlib\animation.py:1064, in Animation.save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1058     _log.info("Disabling savefig.bbox = 'tight', as it may cause "
#    1059               "frame size to vary, which is inappropriate for "
#    1060               "animation.")
#    1061 # canvas._is_saving = True makes the draw_event animation-starting
#    1062 # callback a no-op; canvas.manager = None prevents resizing the GUI
#    1063 # widget (both are likewise done in savefig()).
# -> 1064 with mpl.rc_context({'savefig.bbox': None}), \
#    1065      writer.saving(self._fig, filename, dpi), \
#    1066      cbook._setattr_cm(self._fig.canvas,
#    1067                        _is_saving=True, manager=None):
#    1068     for anim in all_anim:
#    1069         anim._init_draw()  # Clear the initial frame
#
# File c:\Python311\Lib\contextlib.py:155, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     153     value = typ()
#     154 try:
# --> 155     self.gen.throw(typ, value, traceback)
#     156 except StopIteration as exc:
#     157     # Suppress StopIteration *unless* it's the same exception that
#     158     # was passed to throw().  This prevents a StopIteration
#     159     # raised inside the "with" statement from being suppressed.
#     160     return exc is not value
#
# File c:\Python311\Lib\site-packages\matplotlib\animation.py:233, in AbstractMovieWriter.saving(self, fig, outfile, dpi, *args, **kwargs)
#     231     yield self
#     232 finally:
# --> 233     self.finish()
#
# File c:\Python311\Lib\site-packages\matplotlib\animation.py:497, in PillowWriter.finish(self)
#     496 def finish(self):
# --> 497     self._frames[0].save(
#     498         self.outfile, save_all=True, append_images=self._frames[1:],
#     499         duration=int(1000 / self.fps), loop=0)
#
# IndexError: list index out of range
# Error in callback <function _draw_all_if_interactive at 0x000002201DCD9580> (for post_execute):
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File c:\Python311\Lib\site-packages\matplotlib\pyplot.py:119, in _draw_all_if_interactive()
#     117 def _draw_all_if_interactive():
#     118     if matplotlib.is_interactive():
# --> 119         draw_all()
#
# File c:\Python311\Lib\site-packages\matplotlib\_pylab_helpers.py:132, in Gcf.draw_all(cls, force)
#     130 for manager in cls.get_all_fig_managers():
#     131     if force or manager.canvas.figure.stale:
# --> 132         manager.canvas.draw_idle()
#
# File c:\Python311\Lib\site-packages\matplotlib\backend_bases.py:2054, in FigureCanvasBase.draw_idle(self, *args, **kwargs)
#    2052 if not self._is_idle_drawing:
#    2053     with self._idle_draw_cntx():
# -> 2054         self.draw(*args, **kwargs)
#
# File c:\Python311\Lib\site-packages\matplotlib\backends\backend_agg.py:405, in FigureCanvasAgg.draw(self)
#     401 # Acquire a lock on the shared font cache.
#     402 with RendererAgg.lock, \
#     403      (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     404       else nullcontext()):
# --> 405     self.figure.draw(self.renderer)
#     406     # A GUI class may be need to update a window using this draw, so
#     407     # don't forget to call the superclass.
#     408     super().draw()
#
# File c:\Python311\Lib\site-packages\matplotlib\artist.py:74, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      72 @wraps(draw)
#      73 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 74     result = draw(artist, renderer, *args, **kwargs)
#      75     if renderer._rasterizing:
#      76         renderer.stop_rasterizing()
#
# File c:\Python311\Lib\site-packages\matplotlib\artist.py:51, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      48     if artist.get_agg_filter() is not None:
#      49         renderer.start_filter()
# ---> 51     return draw(artist, renderer)
#      52 finally:
#      53     if artist.get_agg_filter() is not None:
#
# File c:\Python311\Lib\site-packages\matplotlib\figure.py:3092, in Figure.draw(self, renderer)
#    3089 finally:
#    3090     self.stale = False
# -> 3092 DrawEvent("draw_event", self.canvas, renderer)._process()
#
# File c:\Python311\Lib\site-packages\matplotlib\backend_bases.py:1230, in Event._process(self)
#    1228 def _process(self):
#    1229     """Generate an event with name ``self.name`` on ``self.canvas``."""
# -> 1230     self.canvas.callbacks.process(self.name, self)
#
# File c:\Python311\Lib\site-packages\matplotlib\cbook\__init__.py:312, in CallbackRegistry.process(self, s, *args, **kwargs)
#     310 except Exception as exc:
#     311     if self.exception_handler is not None:
# --> 312         self.exception_handler(exc)
#     313     else:
#     314         raise
#
# File c:\Python311\Lib\site-packages\matplotlib\cbook\__init__.py:96, in _exception_printer(exc)
#      94 def _exception_printer(exc):
#      95     if _get_running_interactive_framework() in ["headless", None]:
# ---> 96         raise exc
#      97     else:
#      98         traceback.print_exc()
#
# File c:\Python311\Lib\site-packages\matplotlib\cbook\__init__.py:307, in CallbackRegistry.process(self, s, *args, **kwargs)
#     305 if func is not None:
#     306     try:
# --> 307         func(*args, **kwargs)
#     308     # this does not capture KeyboardInterrupt, SystemExit,
#     309     # and GeneratorExit
#     310     except Exception as exc:
#
# File c:\Python311\Lib\site-packages\matplotlib\animation.py:900, in Animation._start(self, *args)
#     897 self._fig.canvas.mpl_disconnect(self._first_draw_id)
#     899 # Now do any initial draw
# --> 900 self._init_draw()
#     902 # Add our callback for stepping the animation and
#     903 # actually start the event_source.
#     904 self.event_source.add_callback(self._step)
#
# File c:\Python311\Lib\site-packages\matplotlib\animation.py:1722, in FuncAnimation._init_draw(self)
#    1714         warnings.warn(
#    1715             "Can not start iterating the frames for the initial draw. "
#    1716             "This can be caused by passing in a 0 length sequence "
#    (...)
#    1719             "it may be exhausted due to a previous display or save."
#    1720         )
#    1721         return
# -> 1722     self._draw_frame(frame_data)
#    1723 else:
#    1724     self._drawn_artists = self._init_func()
#
# File c:\Python311\Lib\site-packages\matplotlib\animation.py:1744, in FuncAnimation._draw_frame(self, framedata)
#    1740 self._save_seq = self._save_seq[-self.save_count:]
#    1742 # Call the func with framedata and args. If blitting is desired,
#    1743 # func needs to return a sequence of any artists that were modified.
# -> 1744 self._drawn_artists = self._func(framedata, *self._args)
#    1746 if self._blit:
#    1748     err = RuntimeError('The animation function must return a sequence '
#    1749                        'of Artist objects.')
#
# d:\RepositoryGitHub\Machine-Learning-Algorithms\Gradient-Decent\gradient-decent-annimation(both-a-and-b).ipynb Cell 8 line 1
#      <a href='vscode-notebook-cell:/d%3A/RepositoryGitHub/Machine-Learning-Algorithms/Gradient-Decent/gradient-decent-annimation%28both-a-and-b%29.ipynb#X10sZmlsZQ%3D%3D?line=11'>12</a> label = 'epoch {0}'.format(i + 1)
#      <a href='vscode-notebook-cell:/d%3A/RepositoryGitHub/Machine-Learning-Algorithms/Gradient-Decent/gradient-decent-annimation%28both-a-and-b%29.ipynb#X10sZmlsZQ%3D%3D?line=12'>13</a> xdata.append(num_epochs[i])
# ---> <a href='vscode-notebook-cell:/d%3A/RepositoryGitHub/Machine-Learning-Algorithms/Gradient-Decent/gradient-decent-annimation%28both-a-and-b%29.ipynb#X10sZmlsZQ%3D%3D?line=13'>14</a> ydata.append(all_b[i])
#      <a href='vscode-notebook-cell:/d%3A/RepositoryGitHub/Machine-Learning-Algorithms/Gradient-Decent/gradient-decent-annimation%28both-a-and-b%29.ipynb#X10sZmlsZQ%3D%3D?line=14'>15</a> line.set_data(xdata, ydata)
#      <a href='vscode-notebook-cell:/d%3A/RepositoryGitHub/Machine-Learning-Algorithms/Gradient-Decent/gradient-decent-annimation%28both-a-and-b%29.ipynb#X10sZmlsZQ%3D%3D?line=15'>16</a> axis.set_xlabel(label)
#
# NameError: name 'all_b' is not defined

# %%
# intercept graph
num_epochs = list(range(0,30))
fig = plt.figure(figsize=(9,5)) 
axis = plt.axes(xlim =(0, 31), ylim =(-150, 50)) 
  
line, = axis.plot([], [], lw = 2) 
  
xdata, ydata = [], [] 
  
# animation function 
def animate(i): 
    label = 'epoch {0}'.format(i + 1)
    xdata.append(num_epochs[i]) 
    ydata.append(all_m[i]) 
    line.set_data(xdata, ydata) 
    axis.set_xlabel(label)
      
    return line, 
  
# calling the animation function     
anim = animation.FuncAnimation(fig, animate, frames = 30,repeat=False, interval = 500)

f = r"animation7.gif" 
writergif = animation.PillowWriter(fps=2) 
anim.save(f, writer=writergif)

# %%
import pandas as pd
import numpy as np

from sklearn.datasets import make_blobs

# %%
centroids = [(-5,-5,5),(5,5,-5),(3.5,-2.5,4),(-2.5,2.5,-4)]
clusters = [1,1,1,1]
x,y = make_blobs(n_samples=1000, cluster_std=clusters, centers=centroids,n_features=3, random_state=1)

# %%
x
# Out:
# array([[ 4.44031858,  6.37975819, -4.3975491 ],
#        [ 5.2590319 ,  5.01444842, -6.47958003],
#        [-5.22876583, -3.38663863,  4.62519531],
#        ...,
#        [-3.96701622, -5.22241403,  6.47016034],
#        [-3.96682315,  2.59038025, -3.72469172],
#        [ 6.49588477,  5.67545381, -4.40078676]])

# %%
y
# Out:
# array([1, 1, 0, 1, 2, 2, 0, 1, 0, 2, 2, 1, 0, 1, 2, 1, 3, 3, 3, 3, 1, 3,
#        1, 1, 0, 1, 0, 2, 0, 3, 0, 0, 0, 1, 2, 1, 3, 0, 3, 1, 0, 2, 1, 3,
#        1, 2, 3, 1, 0, 1, 1, 1, 1, 2, 2, 2, 0, 1, 0, 3, 3, 1, 3, 0, 3, 1,
#        0, 1, 2, 0, 1, 3, 2, 0, 3, 3, 0, 3, 0, 3, 2, 2, 2, 0, 1, 0, 1, 1,
#        0, 3, 2, 2, 2, 2, 3, 1, 0, 1, 3, 1, 0, 0, 1, 3, 1, 2, 2, 1, 0, 3,
#        3, 1, 1, 3, 0, 3, 0, 0, 1, 0, 0, 1, 3, 2, 2, 0, 3, 0, 3, 0, 0, 1,
#        0, 2, 3, 2, 2, 1, 0, 0, 2, 0, 0, 2, 3, 1, 1, 2, 3, 2, 0, 3, 3, 0,
#        1, 2, 3, 3, 2, 2, 2, 0, 0, 0, 1, 3, 3, 1, 1, 3, 0, 0, 0, 3, 3, 1,
#        2, 0, 1, 3, 1, 3, 1, 2, 0, 1, 0, 0, 2, 1, 0, 2, 0, 3, 1, 0, 1, 2,
#        1, 2, 2, 2, 2, 0, 0, 1, 0, 1, 0, 2, 1, 3, 2, 3, 3, 0, 2, 3, 2, 1,
#        0, 3, 3, 2, 1, 0, 2, 3, 0, 3, 2, 2, 1, 3, 3, 2, 3, 3, 3, 0, 1, 0,
#        0, 3, 1, 1, 0, 1, 0, 2, 1, 0, 3, 2, 2, 0, 2, 1, 1, 0, 2, 0, 2, 3,
#        2, 2, 3, 1, 3, 3, 1, 0, 0, 3, 1, 2, 2, 2, 3, 0, 0, 1, 2, 1, 1, 3,
# ...

# %%
df = pd.DataFrame(x)
df
# Out:
#             0         1         2
# 0    4.440319  6.379758 -4.397549
# 1    5.259032  5.014448 -6.479580
# 2   -5.228766 -3.386639  4.625195
# 3    4.376095  5.261875 -5.587029
# 4    4.516996 -2.386889  5.496995
# ..        ...       ...       ...
# 995 -7.304908 -5.031817  5.112488
# 996 -1.814584  1.913340 -3.138954
# 997 -3.967016 -5.222414  6.470160
# 998 -3.966823  2.590380 -3.724692
# 999  6.495885  5.675454 -4.400787
#
# [1000 rows x 3 columns]

# %%
df = df.rename(columns={0:'A',1:'B',2:'3'})

# %%
df
# Out:
#             A         B         3
# 0    4.440319  6.379758 -4.397549
# 1    5.259032  5.014448 -6.479580
# 2   -5.228766 -3.386639  4.625195
# 3    4.376095  5.261875 -5.587029
# 4    4.516996 -2.386889  5.496995
# ..        ...       ...       ...
# 995 -7.304908 -5.031817  5.112488
# 996 -1.814584  1.913340 -3.138954
# 997 -3.967016 -5.222414  6.470160
# 998 -3.966823  2.590380 -3.724692
# 999  6.495885  5.675454 -4.400787
#
# [1000 rows x 3 columns]

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['A'],df['B'])

# %%
from sklearn.cluster import KMeans

# %%
wcss = []
for i in range(1,11):
    km=KMeans(n_clusters=i)
    km.fit_predict(df)
    wcss.append(km.inertia_)
# Out:
# c:\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# ...

# %%
wcss
# Out:
# [56961.424034119394,
#  21255.289068605125,
#  11291.724877772653,
#  2956.8438992838514,
#  2774.9228156209356,
#  2594.069916561103,
#  2418.8264991745446,
#  2282.0340807284083,
#  2135.681046725538,
#  2025.5561286555617]

# %%
plt.figure(figsize=(12,8))
plt.plot(range(1,11),wcss,marker="8")
plt.xlabel("K")
plt.ylabel("WCSS")
# Out:
# Text(0, 0.5, 'WCSS')

# %%
x = df.values

# %%
x
# Out:
# array([[ 4.44031858,  6.37975819, -4.3975491 ],
#        [ 5.2590319 ,  5.01444842, -6.47958003],
#        [-5.22876583, -3.38663863,  4.62519531],
#        ...,
#        [-3.96701622, -5.22241403,  6.47016034],
#        [-3.96682315,  2.59038025, -3.72469172],
#        [ 6.49588477,  5.67545381, -4.40078676]])

# %%
kms=KMeans(n_clusters=4)
y_means=kms.fit_predict(x)
# Out:
# c:\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
y_means
# Out:
# array([0, 0, 1, 0, 3, 3, 1, 0, 1, 3, 3, 0, 1, 0, 3, 0, 2, 2, 2, 2, 0, 2,
#        0, 0, 1, 0, 1, 3, 1, 2, 1, 1, 1, 0, 3, 0, 2, 1, 2, 0, 1, 3, 0, 2,
#        0, 3, 2, 0, 1, 0, 0, 0, 0, 3, 3, 3, 1, 0, 1, 2, 2, 0, 2, 1, 2, 0,
#        1, 0, 3, 1, 0, 2, 3, 1, 2, 2, 1, 2, 1, 2, 3, 3, 3, 1, 0, 1, 0, 0,
#        1, 2, 3, 3, 3, 3, 2, 0, 1, 0, 2, 0, 1, 1, 0, 2, 0, 3, 3, 0, 1, 2,
#        2, 0, 0, 2, 1, 2, 1, 1, 0, 1, 1, 0, 2, 3, 3, 1, 2, 1, 2, 1, 1, 0,
#        1, 3, 2, 3, 3, 0, 1, 1, 3, 1, 1, 3, 2, 0, 0, 3, 2, 3, 1, 2, 2, 1,
#        0, 3, 2, 2, 3, 3, 3, 1, 1, 1, 0, 2, 2, 0, 0, 2, 1, 1, 1, 2, 2, 0,
#        3, 1, 0, 2, 0, 2, 0, 3, 1, 0, 1, 1, 3, 0, 1, 3, 1, 2, 0, 1, 0, 3,
#        0, 3, 3, 3, 3, 1, 1, 0, 1, 0, 1, 3, 0, 2, 3, 2, 2, 1, 3, 2, 3, 0,
#        1, 2, 2, 3, 0, 1, 3, 2, 1, 2, 3, 3, 0, 2, 2, 3, 2, 2, 2, 1, 0, 1,
#        1, 2, 0, 0, 1, 0, 1, 3, 0, 1, 2, 3, 3, 1, 3, 0, 0, 1, 3, 1, 3, 2,
#        3, 3, 2, 0, 2, 2, 0, 1, 1, 2, 0, 3, 3, 3, 2, 1, 1, 0, 3, 0, 0, 2,
# ...

# %%
y
# Out:
# array([1, 1, 0, 1, 2, 2, 0, 1, 0, 2, 2, 1, 0, 1, 2, 1, 3, 3, 3, 3, 1, 3,
#        1, 1, 0, 1, 0, 2, 0, 3, 0, 0, 0, 1, 2, 1, 3, 0, 3, 1, 0, 2, 1, 3,
#        1, 2, 3, 1, 0, 1, 1, 1, 1, 2, 2, 2, 0, 1, 0, 3, 3, 1, 3, 0, 3, 1,
#        0, 1, 2, 0, 1, 3, 2, 0, 3, 3, 0, 3, 0, 3, 2, 2, 2, 0, 1, 0, 1, 1,
#        0, 3, 2, 2, 2, 2, 3, 1, 0, 1, 3, 1, 0, 0, 1, 3, 1, 2, 2, 1, 0, 3,
#        3, 1, 1, 3, 0, 3, 0, 0, 1, 0, 0, 1, 3, 2, 2, 0, 3, 0, 3, 0, 0, 1,
#        0, 2, 3, 2, 2, 1, 0, 0, 2, 0, 0, 2, 3, 1, 1, 2, 3, 2, 0, 3, 3, 0,
#        1, 2, 3, 3, 2, 2, 2, 0, 0, 0, 1, 3, 3, 1, 1, 3, 0, 0, 0, 3, 3, 1,
#        2, 0, 1, 3, 1, 3, 1, 2, 0, 1, 0, 0, 2, 1, 0, 2, 0, 3, 1, 0, 1, 2,
#        1, 2, 2, 2, 2, 0, 0, 1, 0, 1, 0, 2, 1, 3, 2, 3, 3, 0, 2, 3, 2, 1,
#        0, 3, 3, 2, 1, 0, 2, 3, 0, 3, 2, 2, 1, 3, 3, 2, 3, 3, 3, 0, 1, 0,
#        0, 3, 1, 1, 0, 1, 0, 2, 1, 0, 3, 2, 2, 0, 2, 1, 1, 0, 2, 0, 2, 3,
#        2, 2, 3, 1, 3, 3, 1, 0, 0, 3, 1, 2, 2, 2, 3, 0, 0, 1, 2, 1, 1, 3,
# ...

# %%
x[y_means == 0]
# Out:
# array([[ 4.44031858,  6.37975819, -4.3975491 ],
#        [ 5.2590319 ,  5.01444842, -6.47958003],
#        [ 4.37609485,  5.26187548, -5.58702901],
#        [ 6.41767401,  5.05031709, -4.34967679],
#        [ 2.96746021,  6.08109299, -3.27560828],
#        [ 5.40665565,  4.39949566, -5.64863577],
#        [ 5.70098212,  4.80106255, -4.69803995],
#        [ 5.87300584,  6.39408104, -5.58877961],
#        [ 5.96488814,  7.42430662, -2.84964619],
#        [ 6.45167891,  5.3416886 , -5.12517266],
#        [ 5.87619986,  5.12325546, -5.39712568],
#        [ 5.32681298,  3.83955681, -3.47690329],
#        [ 5.27915545,  6.64055365, -4.58912706],
#        [ 4.98099948,  4.77323981, -6.56450785],
#        [ 4.79015305,  6.89716069, -6.38139115],
#        [ 4.79730609,  5.14565182, -7.18102797],
#        [ 5.52265517,  4.64458651, -4.90105775],
#        [ 5.42300321,  4.86575144, -6.78773771],
#        [ 5.74488454,  4.96371871, -5.83239535],
#        [ 3.45560422,  3.45343896, -4.41338148],
# ...

# %%
x[y_means == 0,0]
# Out:
# array([4.44031858, 5.2590319 , 4.37609485, 6.41767401, 2.96746021,
#        5.40665565, 5.70098212, 5.87300584, 5.96488814, 6.45167891,
#        5.87619986, 5.32681298, 5.27915545, 4.98099948, 4.79015305,
#        4.79730609, 5.52265517, 5.42300321, 5.74488454, 3.45560422,
#        5.82779143, 4.63546195, 5.56776474, 3.77042575, 4.4367634 ,
#        3.67351035, 5.16056499, 3.43888011, 6.12775134, 5.51486484,
#        4.79366909, 4.96362136, 4.68777034, 3.90185137, 5.58150928,
#        4.92332064, 5.14936996, 6.56241953, 6.92381543, 6.00819561,
#        4.00237916, 4.19572301, 4.19382179, 5.09499611, 3.11858913,
#        4.43085135, 5.07983961, 3.44730122, 5.93514778, 6.5666862 ,
#        4.91357313, 5.27382709, 4.15608851, 5.08056037, 4.98218245,
#        4.22410518, 5.98857808, 5.8616231 , 5.23333913, 5.39233491,
#        5.99570394, 2.722702  , 5.21633296, 5.30358976, 5.88608992,
#        4.88927159, 5.05837188, 2.69196149, 4.99709455, 4.10972845,
# ...

# %%
cluster = kms.cluster_centers_

# %%
cluster
# Out:
# array([[ 5.12229871,  5.05888892, -4.9826674 ],
#        [-5.01484816, -4.91673399,  5.04389539],
#        [-2.57991446,  2.52052276, -4.02785989],
#        [ 3.55207995, -2.62100184,  4.02121741]])

# %% [markdown]
# ### 2D

# %%
plt.scatter(x[y_means==0,0],x[y_means==0,1],color="Green")
plt.scatter(x[y_means==1,0],x[y_means==1,1],color="red")
plt.scatter(x[y_means==2,0],x[y_means==2,1],color="blue")
plt.scatter(x[y_means==3,0],x[y_means==3,1],color="yellow")
# plt.scatter(X[y_means==4,0],X[y_means==4,1],color="gray") k=5

plt.scatter(cluster[:,0],cluster[:,1],color="black")

# %% [markdown]
# ### 3D

# %%
import plotly.express as ax
fig=ax.scatter_3d(x=x[:,0],y=x[:,1],z=x[:,2])
fig.show()
